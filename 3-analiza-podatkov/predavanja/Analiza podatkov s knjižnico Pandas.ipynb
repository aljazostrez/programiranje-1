# %% [markdown]
# # Analiza podatkov s knjižnico Pandas
#
# Spodaj je pregled najosnovnejših metod, ki jih ponuja knjižnica Pandas. Vsaka od naštetih metod ponuja še cel kup dodatnih možnosti, ki so natančno opisane v [uradni dokumentaciji](http://pandas.pydata.org/pandas-docs/stable/). Z branjem dokumentacije se vam seveda najbolj splača začeti pri [uvodih](http://pandas.pydata.org/pandas-docs/stable/tutorials.html).

# %% [markdown]
# ## Predpriprava

# %%
# naložimo paket
import pandas as pd

# naložimo razpredelnico, s katero bomo delali
filmi = pd.read_csv('obdelani-podatki/filmi.csv', index_col='id')

# ker bomo delali z velikimi razpredelnicami, povemo, da naj se vedno izpiše le 20 vrstic
pd.options.display.max_rows = 20

# %% [markdown]
# ## Osnovni izbori elementov razpredelnic

# %% [markdown]
# Z metodo `.head(n=5)` pogledamo prvih `n`, z metodo `.tail(n=5)` pa zadnjih `n` vrstic razpredelnice.

# %%
filmi.head(10)
# Out:
#                            naslov  dolzina  leto  ocena  metascore  glasovi  \
# id
# 12349                     The Kid       68  1921    8.3        NaN    90443
# 13442  Nosferatu, simfonija groze       94  1922    8.0        NaN    77975
# 15864               Zlata mrzlica       95  1925    8.2        NaN    85136
# 17136                  Metropolis      153  1927    8.3       98.0   136601
# 17925                     General       67  1926    8.2        NaN    68196
# 21749              Luči velemesta       87  1931    8.5        NaN   138228
# 22100      M - mesto isce morilca      117  1931    8.4        NaN   121443
# 24216                   King Kong      100  1933    7.9       90.0    71806
# 25316     Zgodilo se je neke noci      105  1934    8.1       87.0    81390
# 27977                Moderni časi       87  1936    8.5       96.0   179725
#
#          zasluzek                                               opis
# id
# 12349   5450000.0  The Tramp cares for an abandoned child, but ev...
# 13442         NaN  Vampire Count Orlok expresses interest in a ne...
# 15864   5450000.0  A prospector goes to the Klondike in search of...
# 17136     26435.0  In a futuristic city sharply divided between t...
# 17925         NaN  When Union spies steal an engineer's beloved l...
# 21749     19181.0  With the aid of a wealthy erratic tippler, a d...
# 22100     28877.0  When the police in a German city are unable to...
# 24216  10000000.0  A film crew goes to a tropical island for an e...
# 25316         NaN  A spoiled heiress running away from her family...
# 27977    163245.0  The Tramp struggles to live in modern industri...

# %%
filmi.tail()
# Out:
#                       naslov  dolzina  leto  ocena  metascore  glasovi  \
# id
# 5813916               Dag II      135  2016    9.4        NaN    98201
# 5988370                 Reis      108  2017    1.8        NaN    71685
# 6294822  Zamolčani dokumenti      116  2017    7.2       83.0    89674
# 6644200        A Quiet Place       90  2018    7.7       82.0   216675
# 7784604           Hereditary      127  2018    7.3       87.0    90642
#
#             zasluzek                                               opis
# id
# 5813916          NaN  In a desolate war zone where screams of the in...
# 5988370          NaN  A drama about the early life of Recep Tayyip E...
# 6294822   81903458.0  A cover-up that spanned four U.S. Presidents p...
# 6644200  188024361.0  In a post-apocalyptic world, a family is force...
# 7784604   44069456.0  After the family matriarch passes away, a grie...

# %% [markdown]
# Z rezinami pa dostopamo do izbranih vrstic.

# %%
filmi[3:10:2]
# Out:
#                naslov  dolzina  leto  ocena  metascore  glasovi    zasluzek  \
# id
# 17136      Metropolis      153  1927    8.3       98.0   136601     26435.0
# 21749  Luči velemesta       87  1931    8.5        NaN   138228     19181.0
# 24216       King Kong      100  1933    7.9       90.0    71806  10000000.0
# 27977    Moderni časi       87  1936    8.5       96.0   179725    163245.0
#
#                                                     opis
# id
# 17136  In a futuristic city sharply divided between t...
# 21749  With the aid of a wealthy erratic tippler, a d...
# 24216  A film crew goes to a tropical island for an e...
# 27977  The Tramp struggles to live in modern industri...

# %% [markdown]
# Z indeksiranjem razpredelnice dostopamo do posameznih stolpcev.

# %%
filmi['ocena']
# Out:
# id
# 12349      8.3
# 13442      8.0
# 15864      8.2
# 17136      8.3
# 17925      8.2
# 21749      8.5
# 22100      8.4
# 24216      7.9
# 25316      8.1
# 27977      8.5
#           ...
# 5580390    7.4
# 5700672    7.5
# 5715874    7.0
# 5726616    8.0
# 5776858    7.6
# 5813916    9.4
# 5988370    1.8
# 6294822    7.2
# 6644200    7.7
# 7784604    7.3
# Name: ocena, Length: 2500, dtype: float64

# %% [markdown]
# Do stolpcev pogosto dostopamo, zato lahko uporabimo tudi krajši zapis.

# %%
filmi.ocena
# Out:
# id
# 12349      8.3
# 13442      8.0
# 15864      8.2
# 17136      8.3
# 17925      8.2
# 21749      8.5
# 22100      8.4
# 24216      7.9
# 25316      8.1
# 27977      8.5
#           ...
# 5580390    7.4
# 5700672    7.5
# 5715874    7.0
# 5726616    8.0
# 5776858    7.6
# 5813916    9.4
# 5988370    1.8
# 6294822    7.2
# 6644200    7.7
# 7784604    7.3
# Name: ocena, Length: 2500, dtype: float64

# %% [markdown]
# Če želimo več stolpcev, moramo za indeks podati seznam vseh oznak.

# %%
filmi[['naslov', 'ocena']]
# Out:
#                              naslov  ocena
# id
# 12349                       The Kid    8.3
# 13442    Nosferatu, simfonija groze    8.0
# 15864                 Zlata mrzlica    8.2
# 17136                    Metropolis    8.3
# 17925                       General    8.2
# 21749                Luči velemesta    8.5
# 22100        M - mesto isce morilca    8.4
# 24216                     King Kong    7.9
# 25316       Zgodilo se je neke noci    8.1
# 27977                  Moderni časi    8.5
# ...                             ...    ...
# 5580390                 Oblika vode    7.4
# 5700672                  Busanhaeng    7.5
# 5715874     Ubijanje svetega jelena    7.0
# 5726616  Pokliči me po svojem imenu    8.0
# 5776858              Phantom Thread    7.6
# 5813916                      Dag II    9.4
# 5988370                        Reis    1.8
# 6294822         Zamolčani dokumenti    7.2
# 6644200               A Quiet Place    7.7
# 7784604                  Hereditary    7.3
#
# [2500 rows x 2 columns]

# %% [markdown]
# Do vrednosti z indeksom `i` dostopamo z `.iloc[i]`, do tiste s ključem `k` pa z `.loc[k]`.

# %%
filmi.iloc[120]
# Out:
# naslov                                   The French Connection
# dolzina                                                    104
# leto                                                      1971
# ocena                                                      7.8
# metascore                                                   96
# glasovi                                                  95878
# zasluzek                                                   NaN
# opis         A pair of NYC cops in the Narcotics Bureau stu...
# Name: 67116, dtype: object

# %%
filmi.loc[97576]
# Out:
# naslov                 Indiana Jones in Zadnji križarski pohod
# dolzina                                                    127
# leto                                                      1989
# ocena                                                      8.3
# metascore                                                   65
# glasovi                                                 607491
# zasluzek                                           1.97172e+08
# opis         In 1938, after his father Professor Henry Jone...
# Name: 97576, dtype: object

# %% [markdown]
# ## Filtriranje

# %% [markdown]
# Izbor določenih vrstic razpredelnice naredimo tako, da za indeks podamo stolpec logičnih vrednosti, ki ga dobimo z običajnimi operacijami. V vrnjeni razpredelnici bodo ostale vrstice, pri katerih je v stolpcu vrednost `True`.

# %%
filmi.ocena >= 8
# Out:
# id
# 12349       True
# 13442       True
# 15864       True
# 17136       True
# 17925       True
# 21749       True
# 22100       True
# 24216      False
# 25316       True
# 27977       True
#            ...
# 5580390    False
# 5700672    False
# 5715874    False
# 5726616     True
# 5776858    False
# 5813916     True
# 5988370    False
# 6294822    False
# 6644200    False
# 7784604    False
# Name: ocena, Length: 2500, dtype: bool

# %%
filmi[filmi.ocena >= 8]
# Out:
#                                 naslov  dolzina  leto  ocena  metascore  \
# id
# 12349                          The Kid       68  1921    8.3        NaN
# 13442       Nosferatu, simfonija groze       94  1922    8.0        NaN
# 15864                    Zlata mrzlica       95  1925    8.2        NaN
# 17136                       Metropolis      153  1927    8.3       98.0
# 17925                          General       67  1926    8.2        NaN
# 21749                   Luči velemesta       87  1931    8.5        NaN
# 22100           M - mesto isce morilca      117  1931    8.4        NaN
# 25316          Zgodilo se je neke noci      105  1934    8.1       87.0
# 27977                     Moderni časi       87  1936    8.5       96.0
# 31381                        V vrtincu      238  1939    8.2       97.0
# ...                                ...      ...   ...    ...        ...
# 4154756    Maščevalci: Brezmejna vojna      149  2018    8.6       68.0
# 4857264                   Contratiempo      106  2016    8.1        NaN
# 4912910  Mission: Impossible - Fallout      147  2018    8.0       86.0
# 5013056                        Dunkirk      106  2017    8.0       94.0
# 5027774      Trije plakati pred mestom      115  2017    8.2       88.0
# 5074352                         Dangal      161  2016    8.5        NaN
# 5104604                   Isle of Dogs      101  2018    8.0       82.0
# 5311514                 Kimi no na wa.      106  2016    8.4       79.0
# 5726616     Pokliči me po svojem imenu      132  2017    8.0       93.0
# 5813916                         Dag II      135  2016    9.4        NaN
#
#          glasovi     zasluzek  \
# id
# 12349      90443    5450000.0
# 13442      77975          NaN
# 15864      85136    5450000.0
# 17136     136601      26435.0
# 17925      68196          NaN
# 21749     138228      19181.0
# 22100     121443      28877.0
# 25316      81390          NaN
# 27977     179725     163245.0
# 31381     254666  198676459.0
# ...          ...          ...
# 4154756   500755  678815482.0
# 4857264    66508          NaN
# 4912910   140794  219899179.0
# 5013056   422119  188373161.0
# 5027774   283426   54513740.0
# 5074352   105972   12391761.0
# 5104604    74409   32015231.0
# 5311514   109506    5017246.0
# 5726616   127377   18095701.0
# 5813916    98201          NaN
#
#                                                       opis
# id
# 12349    The Tramp cares for an abandoned child, but ev...
# 13442    Vampire Count Orlok expresses interest in a ne...
# 15864    A prospector goes to the Klondike in search of...
# 17136    In a futuristic city sharply divided between t...
# 17925    When Union spies steal an engineer's beloved l...
# 21749    With the aid of a wealthy erratic tippler, a d...
# 22100    When the police in a German city are unable to...
# 25316    A spoiled heiress running away from her family...
# 27977    The Tramp struggles to live in modern industri...
# 31381    A manipulative woman and a roguish man conduct...
# ...                                                    ...
# 4154756  The Avengers and their allies must be willing ...
# 4857264  While the clock is ticking, with the aid of a ...
# 4912910  Ethan Hunt and his IMF team, along with some f...
# 5013056  Allied soldiers from Belgium, the British Empi...
# 5027774  A mother personally challenges the local autho...
# 5074352  Former wrestler Mahavir Singh Phogat and his t...
# 5104604  Set in Japan, Isle of Dogs follows a boy's ody...
# 5311514  Two strangers find themselves linked in a biza...
# 5726616  In 1980s Italy, a romance blossoms between a s...
# 5813916  In a desolate war zone where screams of the in...
#
# [340 rows x 8 columns]

# %%
filmi[(filmi.leto > 2010) & (filmi.ocena > 8)]
# Out:
#                                           naslov  dolzina  leto  ocena  \
# id
# 816692                                Medzvezdje      169  2014    8.6
# 848228                                Maščevalci      143  2012    8.1
# 993846                       Volk z Wall Streeta      180  2013    8.2
# 1201607  Harry Potter in Svetinje smrti - 2. del      130  2011    8.1
# 1291584                                 Bojevnik      140  2011    8.2
# 1345836                        Vzpon Viteza teme      164  2012    8.4
# 1392190                Pobesneli Max: cesta besa      120  2015    8.1
# 1392214                               Ugrabljeni      153  2013    8.1
# 1454029                                Služkinje      146  2011    8.1
# 1675434                               Prijatelja      112  2011    8.5
# ...                                          ...      ...   ...    ...
# 3315342                         Logan: Wolverine      137  2017    8.1
# 3741834                     Lev: Dolga pot domov      118  2016    8.1
# 3783958                             Dežela La la      128  2016    8.1
# 4016934                                Služkinja      144  2016    8.1
# 4154756              Maščevalci: Brezmejna vojna      149  2018    8.6
# 4857264                             Contratiempo      106  2016    8.1
# 5027774                Trije plakati pred mestom      115  2017    8.2
# 5074352                                   Dangal      161  2016    8.5
# 5311514                           Kimi no na wa.      106  2016    8.4
# 5813916                                   Dag II      135  2016    9.4
#
#          metascore  glasovi     zasluzek  \
# id
# 816692        74.0  1216019  188020017.0
# 848228        69.0  1127736  623357910.0
# 993846        75.0   978535  116900694.0
# 1201607       87.0   660265  381011219.0
# 1291584       71.0   390633   13657115.0
# 1345836       78.0  1333877  448139099.0
# 1392190       90.0   737849  153636354.0
# 1392214       74.0   499644   61002302.0
# 1454029       62.0   378363  169708112.0
# 1675434       57.0   637139   13182281.0
# ...            ...      ...          ...
# 3315342       77.0   512587  226277068.0
# 3741834       69.0   166908   51694854.0
# 3783958       93.0   396365  151101803.0
# 4016934       84.0    67471    2005473.0
# 4154756       68.0   500755  678815482.0
# 4857264        NaN    66508          NaN
# 5027774       88.0   283426   54513740.0
# 5074352        NaN   105972   12391761.0
# 5311514       79.0   109506    5017246.0
# 5813916        NaN    98201          NaN
#
#                                                       opis
# id
# 816692   A team of explorers travel through a wormhole ...
# 848228   Earth's mightiest heroes must come together an...
# 993846   Based on the true story of Jordan Belfort, fro...
# 1201607  Harry, Ron, and Hermione search for Voldemort'...
# 1291584  The youngest son of an alcoholic former boxer ...
# 1345836  Eight years after the Joker's reign of anarchy...
# 1392190  In a post-apocalyptic wasteland, a woman rebel...
# 1392214  When Keller Dover's daughter and her friend go...
# 1454029  An aspiring author during the civil rights mov...
# 1675434  After he becomes a quadriplegic from a paragli...
# ...                                                    ...
# 3315342  In the near future, a weary Logan cares for an...
# 3741834  A five-year-old Indian boy gets lost on the st...
# 3783958  While navigating their careers in Los Angeles,...
# 4016934  A woman is hired as a handmaiden to a Japanese...
# 4154756  The Avengers and their allies must be willing ...
# 4857264  While the clock is ticking, with the aid of a ...
# 5027774  A mother personally challenges the local autho...
# 5074352  Former wrestler Mahavir Singh Phogat and his t...
# 5311514  Two strangers find themselves linked in a biza...
# 5813916  In a desolate war zone where screams of the in...
#
# [39 rows x 8 columns]

# %% [markdown]
# ### Naloga
#
# Poiščite filme, ki si jih želimo izogniti za vsako ceno, torej tiste, ki so daljši od dveh ur in imajo oceno pod 6.5.

# %%
filmi[(filmi.ocena < 6) & (filmi.dolzina > 150)]
# Out:
#                                 naslov  dolzina  leto  ocena  metascore  \
# id
# 346491                       Alexander      175  2004    5.6       39.0
# 1190080                           2012      158  2009    5.8       49.0
# 2109248   Transformerji: Doba izumrtja      165  2014    5.7       32.0
# 3371366  Transformers: The Last Knight      154  2017    5.2       27.0
#
#          glasovi     zasluzek  \
# id
# 346491    151255   34297191.0
# 1190080   318182  166112167.0
# 2109248   275439  245439076.0
# 3371366   106857  130168683.0
#
#                                                       opis
# id
# 346491   Alexander, the King of Macedonia and one of th...
# 1190080  A frustrated writer struggles to keep his fami...
# 2109248  Autobots must escape sight from a bounty hunte...
# 3371366  Autobots and Decepticons are at war, with huma...

# %% [markdown]
# ## Urejanje

# %% [markdown]
# Razpredelnico urejamo z metodo `.sort_values`, ki ji podamo ime ali seznam imen stolpcev, po katerih želimo urejati. Po želji lahko tudi povemo, kateri stolpci naj bodo urejeni naraščajoče in kateri padajoče.

# %%
filmi.sort_values('dolzina')
# Out:
#                                     naslov  dolzina  leto  ocena  metascore  \
# id
# 33563                                Dumbo       64  1941    7.3        NaN
# 17925                              General       67  1926    8.2        NaN
# 12349                              The Kid       68  1921    8.3        NaN
# 95489                 The Land Before Time       69  1988    7.4       66.0
# 154506                           Following       69  1998    7.6       60.0
# 34492                                Bambi       70  1942    7.3        NaN
# 42332                              Pepelka       74  1950    7.3        NaN
# 43274                  Alice in Wonderland       75  1951    7.4        NaN
# 53285                    Uspavana lepotica       75  1959    7.3        NaN
# 107688                    Predbozicna mora       76  1993    8.0       82.0
# ...                                    ...      ...   ...    ...        ...
# 71562                       Boter, II. del      202  1974    9.0       90.0
# 104797                           Malcolm X      202  1992    7.7       72.0
# 47478                      Sedem samurajev      207  1954    8.7       98.0
# 367110              Swades: We, the People      210  2004    8.3        NaN
# 52618                              Ben Hur      212  1959    8.1       90.0
# 56172                     Lawrence Arabski      216  1962    8.3      100.0
# 169102   Lagaan: Once Upon a Time in India      224  2001    8.1       84.0
# 87843              Bilo je nekoč v Ameriki      229  1984    8.4        NaN
# 31381                            V vrtincu      238  1939    8.2       97.0
# 1954470                 Gangs of Wasseypur      321  2012    8.2       89.0
#
#          glasovi     zasluzek  \
# id
# 33563     101658    1600000.0
# 17925      68196          NaN
# 12349      90443    5450000.0
# 95489      70578   48092846.0
# 154506     76161      48482.0
# 34492     111839  102797150.0
# 42332     125231   85000000.0
# 43274     111337          NaN
# 53285     117135   51600000.0
# 107688    257315   75082668.0
# ...          ...          ...
# 71562     950252   57300000.0
# 104797     73041   48169908.0
# 47478     271348     269061.0
# 367110     71486    1223240.0
# 52618     194343   74700000.0
# 56172     231792   44824144.0
# 169102     89025      70147.0
# 87843     264440    5321508.0
# 31381     254666  198676459.0
# 1954470    64931          NaN
#
#                                                       opis
# id
# 33563    Ridiculed because of his enormous ears, a youn...
# 17925    When Union spies steal an engineer's beloved l...
# 12349    The Tramp cares for an abandoned child, but ev...
# 95489    An orphaned brontosaurus teams up with other y...
# 154506   A young writer who follows strangers for mater...
# 34492    The story of a young deer growing up in the fo...
# 42332    When Cinderella's cruel stepmother prevents he...
# 43274    Alice stumbles into the world of Wonderland. W...
# 53285    After being snubbed by the royal family, a mal...
# 107688   Jack Skellington, king of Halloween Town, disc...
# ...                                                    ...
# 71562    The early life and career of Vito Corleone in ...
# 104797   Biographical epic of the controversial and inf...
# 47478    A poor village under attack by bandits recruit...
# 367110   A successful Indian scientist returns to an In...
# 52618    When a Jewish prince is betrayed and sent into...
# 56172    The story of T.E. Lawrence, the English office...
# 169102   The people of a small village in Victorian Ind...
# 87843    A former Prohibition-era Jewish gangster retur...
# 31381    A manipulative woman and a roguish man conduct...
# 1954470  A clash between Sultan and Shahid Khan leads t...
#
# [2500 rows x 8 columns]

# %%
# najprej uredi padajoče po oceni, pri vsaki oceni pa še naraščajoče po letu
filmi.sort_values(['ocena', 'leto'], ascending=[False, True])
# Out:
#                                       naslov  dolzina  leto  ocena  metascore  \
# id
# 5813916                               Dag II      135  2016    9.4        NaN
# 111161                  Kaznilnica odrešitve      142  1994    9.3       80.0
# 68646                                  Boter      175  1972    9.2      100.0
# 71562                         Boter, II. del      202  1974    9.0       90.0
# 468569                            Vitez teme      152  2008    9.0       84.0
# 50083                          12 jeznih mož       96  1957    8.9       96.0
# 60196                    Dober, grd, hudoben      161  1966    8.9       90.0
# 108052                   Schindlerjev seznam      195  1993    8.9       93.0
# 110912                                  Šund      154  1994    8.9       94.0
# 167260   Gospodar prstanov: Kraljeva vrnitev      201  2003    8.9       94.0
# ...                                      ...      ...   ...    ...        ...
# 118688                       Batman in Robin      125  1997    3.7       28.0
# 368226                              The Room       99  2003    3.6        9.0
# 327554                              Catwoman      104  2004    3.3       27.0
# 810913                          Jack in Jill       91  2011    3.3       23.0
# 1073498                    Meet the Spartans       86  2008    2.7        9.0
# 1098327                 Dragonball Evolution       85  2009    2.6       45.0
# 185183                     Battlefield Earth      118  2000    2.4        9.0
# 799949                            Velik film       86  2007    2.3       17.0
# 1213644                       Disaster Movie       87  2008    1.9       15.0
# 5988370                                 Reis      108  2017    1.8        NaN
#
#          glasovi     zasluzek  \
# id
# 5813916    98201          NaN
# 111161   2003395   28341469.0
# 68646    1372528  134966411.0
# 71562     950252   57300000.0
# 468569   1972591  534858444.0
# 50083     560979          NaN
# 60196     593780    6100000.0
# 108052   1033853   96067179.0
# 110912   1564051  107928762.0
# 167260   1426365  377845905.0
# ...          ...          ...
# 118688    211646  107325195.0
# 368226     66751          NaN
# 327554     98258   40202379.0
# 810913     68713   74158157.0
# 1073498    95557   38233676.0
# 1098327    63966    9353573.0
# 185183     71149   21471685.0
# 799949     96182   39739367.0
# 1213644    80828   14190901.0
# 5988370    71685          NaN
#
#                                                       opis
# id
# 5813916  In a desolate war zone where screams of the in...
# 111161   Two imprisoned men bond over a number of years...
# 68646    The aging patriarch of an organized crime dyna...
# 71562    The early life and career of Vito Corleone in ...
# 468569   When the menace known as the Joker emerges fro...
# 50083    A jury holdout attempts to prevent a miscarria...
# 60196    A bounty hunting scam joins two men in an unea...
# 108052   In German-occupied Poland during World War II,...
# 110912   The lives of two mob hitmen, a boxer, a gangst...
# 167260   Gandalf and Aragorn lead the World of Men agai...
# ...                                                    ...
# 118688   Batman and Robin try to keep their relationshi...
# 368226   Johnny is a successful banker who lives happil...
# 327554   A shy woman, endowed with the speed, reflexes,...
# 810913   Family guy Jack Sadelstein prepares for the an...
# 1073498  The heroic Spartan king Leonidas, armed with n...
# 1098327  The young warrior Son Goku sets out on a quest...
# 185183   It's the year 3000 A.D.; the Earth is lost to ...
# 799949   A comedic satire of films that are large in sc...
# 1213644  Over the course of one evening, an unsuspectin...
# 5988370  A drama about the early life of Recep Tayyip E...
#
# [2500 rows x 8 columns]

# %% [markdown]
# ## Združevanje

# %% [markdown]
# Z metodo `.groupby` ustvarimo razpredelnico posebne vrste, v katerem so vrstice združene glede na skupno lastnost.

# %%
filmi_po_letih = filmi.groupby('leto')

# %%
filmi_po_letih

# %%
# povprečna ocena vsakega leta
filmi_po_letih.ocena.mean()
# Out:
# leto
# 1921    8.300000
# 1922    8.000000
# 1925    8.200000
# 1926    8.200000
# 1927    8.300000
# 1931    8.450000
# 1933    7.900000
# 1934    8.100000
# 1936    8.500000
# 1937    7.600000
#           ...
# 2009    6.725893
# 2010    6.699130
# 2011    6.675000
# 2012    6.811215
# 2013    6.786047
# 2014    6.883333
# 2015    6.844944
# 2016    6.896154
# 2017    6.879710
# 2018    7.050000
# Name: ocena, Length: 87, dtype: float64

# %% [markdown]
# Če želimo, lahko združujemo tudi po izračunanih lastnostih. Izračunajmo stolpec in ga shranimo v razpredelnico.

# %%
filmi['desetletje'] = 10 * (filmi.leto // 10)

# %%
filmi
# Out:
#                              naslov  dolzina  leto  ocena  metascore  glasovi  \
# id
# 12349                       The Kid       68  1921    8.3        NaN    90443
# 13442    Nosferatu, simfonija groze       94  1922    8.0        NaN    77975
# 15864                 Zlata mrzlica       95  1925    8.2        NaN    85136
# 17136                    Metropolis      153  1927    8.3       98.0   136601
# 17925                       General       67  1926    8.2        NaN    68196
# 21749                Luči velemesta       87  1931    8.5        NaN   138228
# 22100        M - mesto isce morilca      117  1931    8.4        NaN   121443
# 24216                     King Kong      100  1933    7.9       90.0    71806
# 25316       Zgodilo se je neke noci      105  1934    8.1       87.0    81390
# 27977                  Moderni časi       87  1936    8.5       96.0   179725
# ...                             ...      ...   ...    ...        ...      ...
# 5580390                 Oblika vode      123  2017    7.4       87.0   255564
# 5700672                  Busanhaeng      118  2016    7.5       72.0    96341
# 5715874     Ubijanje svetega jelena      121  2017    7.0       73.0    73468
# 5726616  Pokliči me po svojem imenu      132  2017    8.0       93.0   127377
# 5776858              Phantom Thread      130  2017    7.6       90.0    71395
# 5813916                      Dag II      135  2016    9.4        NaN    98201
# 5988370                        Reis      108  2017    1.8        NaN    71685
# 6294822         Zamolčani dokumenti      116  2017    7.2       83.0    89674
# 6644200               A Quiet Place       90  2018    7.7       82.0   216675
# 7784604                  Hereditary      127  2018    7.3       87.0    90642
#
#             zasluzek                                               opis  \
# id
# 12349      5450000.0  The Tramp cares for an abandoned child, but ev...
# 13442            NaN  Vampire Count Orlok expresses interest in a ne...
# 15864      5450000.0  A prospector goes to the Klondike in search of...
# 17136        26435.0  In a futuristic city sharply divided between t...
# 17925            NaN  When Union spies steal an engineer's beloved l...
# 21749        19181.0  With the aid of a wealthy erratic tippler, a d...
# 22100        28877.0  When the police in a German city are unable to...
# 24216     10000000.0  A film crew goes to a tropical island for an e...
# 25316            NaN  A spoiled heiress running away from her family...
# 27977       163245.0  The Tramp struggles to live in modern industri...
# ...              ...                                                ...
# 5580390   63859435.0  At a top secret research facility in the 1960s...
# 5700672    2129768.0  While a zombie virus breaks out in South Korea...
# 5715874    2291901.0  Steven, a charismatic surgeon, is forced to ma...
# 5726616   18095701.0  In 1980s Italy, a romance blossoms between a s...
# 5776858   21023275.0  Set in 1950's London, Reynolds Woodcock is a r...
# 5813916          NaN  In a desolate war zone where screams of the in...
# 5988370          NaN  A drama about the early life of Recep Tayyip E...
# 6294822   81903458.0  A cover-up that spanned four U.S. Presidents p...
# 6644200  188024361.0  In a post-apocalyptic world, a family is force...
# 7784604   44069456.0  After the family matriarch passes away, a grie...
#
#          desetletje
# id
# 12349          1920
# 13442          1920
# 15864          1920
# 17136          1920
# 17925          1920
# 21749          1930
# 22100          1930
# 24216          1930
# 25316          1930
# 27977          1930
# ...             ...
# 5580390        2010
# 5700672        2010
# 5715874        2010
# 5726616        2010
# 5776858        2010
# 5813916        2010
# 5988370        2010
# 6294822        2010
# 6644200        2010
# 7784604        2010
#
# [2500 rows x 9 columns]

# %%
filmi_po_desetletjih = filmi.groupby('desetletje')

# %% [markdown]
# Preštejemo, koliko filmov je bilo v vsakem desetletju. Pri večini stolpcev dobimo iste številke, ker imamo v vsakem stolpcu enako vnosov. Če kje kakšen podatek manjkal, je številka manjša.

# %%
filmi_po_desetletjih.count()
# Out:
#             naslov  dolzina  leto  ocena  metascore  glasovi  zasluzek  opis
# desetletje
# 1920             5        5     5      5          1        5         3     5
# 1930             9        9     9      9          7        9         8     9
# 1940            18       18    18     18         10       18        13    18
# 1950            35       35    35     35         19       35        22    35
# 1960            47       47    47     47         34       47        36    47
# 1970            64       64    64     64         61       64        56    64
# 1980           164      164   164    164        154      164       158   164
# 1990           396      396   396    396        375      396       395   396
# 2000           899      899   899    899        882      899       882   899
# 2010           863      863   863    863        853      863       847   863

# %% [markdown]
# Če želimo dobiti le število članov posamezne skupine, uporabimo metodo `.size()`. V tem primeru dobimo le stolpec, ne razpredelnice.

# %%
filmi_po_desetletjih.size()
# Out:
# desetletje
# 1920      5
# 1930      9
# 1940     18
# 1950     35
# 1960     47
# 1970     64
# 1980    164
# 1990    396
# 2000    899
# 2010    863
# dtype: int64

# %% [markdown]
# Pogledamo povprečja vsakega desetletja. Dobimo povprečno leto, povprečno dolžino in oceno. Povprečnega naslova ne dobimo, ker se ga ne da izračunati, zato ustreznega stolpca ni.

# %%
filmi_po_desetletjih.mean()
# Out:
#                dolzina         leto     ocena  metascore        glasovi  \
# desetletje
# 1920         95.400000  1924.200000  8.200000  98.000000   91670.200000
# 1930        116.444444  1935.444444  8.155556  91.142857  159804.555556
# 1940        105.722222  1943.444444  8.072222  94.400000  154435.388889
# 1950        109.057143  1954.600000  8.077143  93.473684  149282.514286
# 1960        127.872340  1964.425532  7.891489  81.088235  157029.000000
# 1970        120.046875  1975.281250  7.768750  77.901639  230599.203125
# 1980        111.939024  1985.414634  7.420732  64.902597  181266.146341
# 1990        115.957071  1995.535354  7.059596  61.584000  210144.161616
# 2000        112.181313  2005.040044  6.818576  57.904762  200504.091212
# 2010        113.567787  2013.333720  6.807300  58.975381  196399.928158
#
#                 zasluzek
# desetletje
# 1920        3.642145e+06
# 1930        5.320198e+07
# 1940        2.284421e+07
# 1950        2.592219e+07
# 1960        4.477990e+07
# 1970        6.823634e+07
# 1980        7.153909e+07
# 1990        7.800289e+07
# 2000        7.656505e+07
# 2010        8.927642e+07

# %% [markdown]
# ### Naloga
#
# Izračunajte število filmov posamezne dolžine, zaokrožene na 5 minut.

# %% [markdown]
# ## Risanje grafov

# %%
# vključimo risanje grafov (če stvari začnejo delati počasneje, izklopimo možnost inline)
# %matplotlib inline

# %% [markdown]
# Običajen graf dobimo z metodo `plot`. Uporabljamo ga, kadar želimo prikazati spreminjanje vrednosti v odvisnosti od zvezne spremenljivke. Naša hipoteza je, da so zlata leta filma mimo. Graf to potrjuje.

# %%
filmi[filmi.ocena > 8.5].groupby('desetletje').size().plot()

# %% [markdown]
# Razsevni diagram dobimo z metodo `plot.scatter`. Uporabljamo ga, če želimo ugotoviti povezavo med dvema spremenljivkama.

# %%
filmi.plot.scatter('dolzina', 'ocena')

# %%
filmi[filmi.dolzina < 250].plot.scatter('dolzina', 'ocena')

# %% [markdown]
# Stolpčni diagram dobimo z metodo `plot.bar`. Uporabljamo ga, če želimo primerjati vrednosti pri diskretnih (običajno kategoričnih) spremenljivkah. Pogosto je koristno, da graf uredimo po vrednostih.

# %%
filmi.sort_values('zasluzek', ascending=False).head(20).plot.bar(x='naslov', y='zasluzek')

# %% [markdown]
# ### Naloga
#
# Narišite grafe, ki ustrezno kažejo:
# - Povezavo med IMDB in metascore oceno
# - Spreminjanje povprečne dolžine filmov skozi leta

# %%
filmi.plot.scatter('metascore', 'ocena')

# %% [markdown]
# ## Stikanje

# %%
osebe = pd.read_csv('obdelani-podatki/osebe.csv', index_col='id')
vloge = pd.read_csv('obdelani-podatki/vloge.csv')
zanri = pd.read_csv('obdelani-podatki/zanri.csv')

# %% [markdown]
# Razpredelnice stikamo s funkcijo `merge`, ki vrne razpredelnico vnosov iz obeh tabel, pri katerih se vsi istoimenski podatki ujemajo.

# %%
vloge[vloge.film == 12349]
# Out:
#     film   oseba    vloga
# 0  12349     122  igralec
# 1  12349     122  reziser
# 2  12349    1067  igralec
# 3  12349  588033  igralec
# 4  12349  701012  igralec

# %%
zanri[zanri.film == 12349]
# Out:
#     film    zanr
# 0  12349  Comedy
# 1  12349   Drama
# 2  12349  Family

# %%
pd.merge(vloge, zanri).head(20)
# Out:
#      film   oseba    vloga     zanr
# 0   12349     122  igralec   Comedy
# 1   12349     122  igralec    Drama
# 2   12349     122  igralec   Family
# 3   12349     122  reziser   Comedy
# 4   12349     122  reziser    Drama
# 5   12349     122  reziser   Family
# 6   12349    1067  igralec   Comedy
# 7   12349    1067  igralec    Drama
# 8   12349    1067  igralec   Family
# 9   12349  588033  igralec   Comedy
# 10  12349  588033  igralec    Drama
# 11  12349  588033  igralec   Family
# 12  12349  701012  igralec   Comedy
# 13  12349  701012  igralec    Drama
# 14  12349  701012  igralec   Family
# 15  13442    3638  reziser  Fantasy
# 16  13442    3638  reziser   Horror
# 17  13442  334603  igralec  Fantasy
# 18  13442  334603  igralec   Horror
# 19  13442  775180  igralec  Fantasy

# %% [markdown]
# V osnovi vsebuje staknjena razpredelnica le tiste vnose, ki se pojavijo v obeh tabelah. Temu principu pravimo notranji stik (_inner join_). Lahko pa se odločimo, da izberemo tudi tiste vnose, ki imajo podatke le v levi tabeli (_left join_), le v desni tabeli (_right join_) ali v vsaj eni tabeli (_outer join_). Če v eni tabeli ni vnosov, bodo v staknjeni tabeli označene manjkajoče vrednosti. Ker smo v našem primeru podatke jemali iz IMDBja, kjer so za vsak film določeni tako žanri kot vloge, do razlik ne pride.

# %% [markdown]
# Včasih želimo stikati tudi po stolpcih z različnimi imeni. V tem primeru funkciji `merge` podamo argumenta `left_on` in `right_on`.

# %%
pd.merge(pd.merge(vloge, zanri), osebe, left_on='oseba', right_on='id')
# Out:
#           film    oseba    vloga       zanr                 ime
# 0        12349      122  igralec     Comedy     Charles Chaplin
# 1        12349      122  igralec      Drama     Charles Chaplin
# 2        12349      122  igralec     Family     Charles Chaplin
# 3        12349      122  reziser     Comedy     Charles Chaplin
# 4        12349      122  reziser      Drama     Charles Chaplin
# 5        12349      122  reziser     Family     Charles Chaplin
# 6        15864      122  igralec  Adventure     Charles Chaplin
# 7        15864      122  igralec     Comedy     Charles Chaplin
# 8        15864      122  igralec      Drama     Charles Chaplin
# 9        15864      122  reziser  Adventure     Charles Chaplin
# ...        ...      ...      ...        ...                 ...
# 33694  6644200  8075925  igralec    Mystery  Millicent Simmonds
# 33695  7784604  1842974  igralec      Drama          Alex Wolff
# 33696  7784604  1842974  igralec     Horror          Alex Wolff
# 33697  7784604  1842974  igralec    Mystery          Alex Wolff
# 33698  7784604  4170048  reziser      Drama           Ari Aster
# 33699  7784604  4170048  reziser     Horror           Ari Aster
# 33700  7784604  4170048  reziser    Mystery           Ari Aster
# 33701  7784604  8412536  igralec      Drama       Milly Shapiro
# 33702  7784604  8412536  igralec     Horror       Milly Shapiro
# 33703  7784604  8412536  igralec    Mystery       Milly Shapiro
#
# [33704 rows x 5 columns]

# %% [markdown]
# Poglejmo, katera osebe so nastopale v največ komedijah.

# %%
zanri_oseb = pd.merge(pd.merge(vloge, zanri), osebe, left_on='oseba', right_on='id')
zanri_oseb[
    (zanri_oseb.zanr == 'Comedy') &
    (zanri_oseb.vloga == 'igralec')
].groupby(
    'ime'
).size(
).sort_values(
    ascending=False
).head(20)
# Out:
# ime
# Adam Sandler           26
# Ben Stiller            20
# Jim Carrey             19
# Owen Wilson            19
# Cameron Diaz           18
# Steve Carell           18
# Will Ferrell           16
# Robert De Niro         14
# Bill Murray            14
# Seth Rogen             13
# Robin Williams         13
# Paul Rudd              13
# Jonah Hill             13
# Ryan Reynolds          12
# Jennifer Aniston       12
# Jack Black             12
# Vince Vaughn           12
# Tom Hanks              12
# Eddie Murphy           12
# Seann William Scott    11
# dtype: int64

# %% [markdown]
# ### Naloga
#
# - Izračunajte povprečno oceno vsakega žanra.
# - Kateri režiserji snemajo najdonosnejše filme?

# %% [markdown]
# ## Zahtevnejši primer: naivni Bayesov klasifikator

# %% [markdown]
# Zanima nas, ali lahko iz opisa filma napovemo njegove žanre. Gre za _klasifikacijski problem_, saj želimo filme klasificirati v žanre, naša naloga pa je napisati ustrezen program, ki mu pravimo _klasifikator_. Da zadevo naredimo bolj obvladljivo, bomo opis predstavili le z množico korenov besed, ki se v opisu pojavljajo.

# %%
def koren_besede(beseda):
    beseda = ''.join(znak for znak in beseda if znak.isalpha())
    if not beseda:
        return '$'
    konec = len(beseda) - 1
    if beseda[konec] in 'ds':
        konec -= 1
    while konec >= 0 and beseda[konec] in 'aeiou':
        konec -= 1
    return beseda[:konec + 1]

def koreni_besed(niz):
    return {
        koren_besede(beseda) for beseda in niz.replace('-', ' ').lower().split() if beseda
    }

# %%
koreni_besed("In 1938, after his father Professor Henry Jones, Sr. goes missing while pursuing the Holy Grail, Indiana Jones finds himself up against Adolf Hitler's Nazis again to stop them obtaining its powers.")
# Out:
# {'$',
#  'adolf',
#  'after',
#  'again',
#  'against',
#  'father',
#  'find',
#  'g',
#  'grail',
#  'h',
#  'henry',
#  'himself',
#  'hitler',
#  'holy',
#  'in',
#  'indian',
#  'it',
#  'jon',
#  'missing',
#  'naz',
#  'obtaining',
#  'power',
#  'professor',
#  'pursuing',
#  'sr',
#  'stop',
#  't',
#  'th',
#  'them',
#  'up',
#  'whil'}

# %% [markdown]
# Zanimala nas bo torej verjetnost, da ima film žanr $Ž_i$ ob pogoju, da njegov opis vsebuje korene $K_1, \ldots, K_m$, torej
#
# $$P(Ž_i | K_1 \cap \cdots \cap K_n)$$
#
# Pri tem se bomo poslužili Bayesovega izreka
#
# $$P(A | B) = \frac{P(A \cap B)}{P(B)} = \frac{P(B | A) \cdot P(A)}{P(B)}$$
#
# zaradi česar našemu klasifikatorju pravimo _Bayesov klasifikator_. Velja
#
# $$P(Ž_i | K_1 \cap \cdots \cap K_n) = \frac{P(K_1 \cap \cdots \cap K_n | Ž_i) \cdot P(Ž_i)}{P(K_1 \cap \cdots \cap K_n)}$$
#
# Nadalje si nalogo poenostavimo s predpostavko, da so pojavitve besed med seboj neodvisne. To sicer ni res, na primer ob besedi _treasure_ se bolj pogosto pojavlja beseda _hidden_ kot na primer _boring_, zato pravimo, da je klasifikator _naiven_. Ob tej predpostavki velja:
#
# $$P(K_1 \cap \cdots \cap K_n | Ž_i) = P(K_1 | Ž_i) \cdot \cdots \cdot P(K_n | Ž_i)$$
#
# oziroma
#
# $$P(Ž_i | K_1 \cap \cdots \cap K_n) = \frac{P(K_1 | Ž_i) \cdot \cdots \cdot P(K_n | Ž_i) \cdot P(Ž_i)}{P(K_1 \cap \cdots \cap K_n)}$$
#
# Filmu, katerega opis vsebuje korene $K_1, \dots, K_n$ bomo priredili tiste žanre $Ž_i$, pri katerih je dana verjetnost največja. Ker imenovalec ni odvisen od žanra, moramo torej za vsak $Ž_i$ izračunati le števec:
#
# $$P(K_1 | Ž_i) \cdot \cdots \cdot P(K_n | Ž_i) \cdot P(Ž_i)$$
#
# Vse te podatke znamo izračunati, zato se lahko lotimo dela.

# %% [markdown]
# Verjetnost posameznega žanra $P(Ž)$ izračunamo brez večjih težav:

# %%
verjetnosti_zanrov = zanri.groupby('zanr').size() / len(filmi)
verjetnosti_zanrov
# Out:
# zanr
# Action       0.3116
# Adventure    0.2728
# Animation    0.0648
# Biography    0.0648
# Comedy       0.3240
# Crime        0.1960
# Drama        0.4752
# Family       0.0592
# Fantasy      0.1080
# Film-Noir    0.0040
#               ...
# Horror       0.1020
# Music        0.0180
# Musical      0.0088
# Mystery      0.1044
# Romance      0.1392
# Sci-Fi       0.1164
# Sport        0.0196
# Thriller     0.1892
# War          0.0168
# Western      0.0068
# Length: 21, dtype: float64

# %% [markdown]
# Verjetnosti $P(K|Ž)$ bomo shranili v razpredelnico, v kateri bodo vrstice ustrezale korenom $K$, stolpci pa žanrom $Ž$. Najprej moramo poiskati vse filme, ki imajo žanr $Ž$, njihov opis pa vsebuje koren $K$. Vzemimo vse opise filmov:

# %%
filmi.opis
# Out:
# id
# 12349      The Tramp cares for an abandoned child, but ev...
# 13442      Vampire Count Orlok expresses interest in a ne...
# 15864      A prospector goes to the Klondike in search of...
# 17136      In a futuristic city sharply divided between t...
# 17925      When Union spies steal an engineer's beloved l...
# 21749      With the aid of a wealthy erratic tippler, a d...
# 22100      When the police in a German city are unable to...
# 24216      A film crew goes to a tropical island for an e...
# 25316      A spoiled heiress running away from her family...
# 27977      The Tramp struggles to live in modern industri...
#                                  ...
# 5580390    At a top secret research facility in the 1960s...
# 5700672    While a zombie virus breaks out in South Korea...
# 5715874    Steven, a charismatic surgeon, is forced to ma...
# 5726616    In 1980s Italy, a romance blossoms between a s...
# 5776858    Set in 1950's London, Reynolds Woodcock is a r...
# 5813916    In a desolate war zone where screams of the in...
# 5988370    A drama about the early life of Recep Tayyip E...
# 6294822    A cover-up that spanned four U.S. Presidents p...
# 6644200    In a post-apocalyptic world, a family is force...
# 7784604    After the family matriarch passes away, a grie...
# Name: opis, Length: 2500, dtype: object

# %% [markdown]
# To vrsto nizov pretvorimo v vrsto množic besed. Uporabimo metodo `apply`, ki dano funkcijo uporabi na vsakem vnosu.

# %%
filmi.opis.apply(
    koreni_besed
)
# Out:
# id
# 12349      {tramp, jeopardy, chil, th, for, relationship,...
# 13442      {, vampir, real, interest, estat, wif, in, age...
# 15864      {, find, mor, klondik, th, in, gol, of, prospe...
# 17136      {, sharply, mastermin, their, clas, prophet, p...
# 17925      {engineer, steal, lin, belov, union, singl, h,...
# 21749      {, wealthy, fallen, h, tippler, girl, dewy, si...
# 22100      {, manhunt, polic, chil, criminal, th, in, cat...
# 24216      {, star, h, captur, then, exotic, their, tropi...
# 25316      {, running, heires, her, n, story, by, in, fam...
# 27977      {, tramp, with, th, in, struggl, society, help...
#                                  ...
# 5580390    {, top, facility, uniq, that, hel, lonely, res...
# 5700672    {, struggl, passenger, south, whil, on, busan,...
# 5715874    {, teenag, h, lif, steven, sacrific, behavior,...
# 5726616    {, between, year, seventeen, h, father, resear...
# 5776858    {, disrupt, whos, lif, dressmaker, h, woodcock...
# 5813916    {, $, ech, death, valor, innocent, wher, on, w...
# 5988370    {, dram, $, erdogan, lif, h, career, early, po...
# 6294822    {, pres, spann, newspaper, that, country, unpr...
# 6644200    {, silenc, apocalyptic, with, whil, hearing, i...
# 7784604    {, family, grieving, matriarch, pass, dark, di...
# Name: opis, Length: 2500, dtype: object

# %% [markdown]
# Po nekaj [iskanja po internetu](https://stackoverflow.com/questions/30885005/pandas-series-of-lists-to-one-series) in masiranja pridemo do iskane razpredelnice:

# %%
koreni_filmov = filmi.opis.apply(
    koreni_besed
).apply(
    list
).apply(
    pd.Series
).stack(
).reset_index(
    level='id'
).rename(columns={
    'id': 'film',
    0: 'koren',
})
koreni_filmov
# Out:
#        film         koren
# 0     12349         tramp
# 1     12349      jeopardy
# 2     12349          chil
# 3     12349            th
# 4     12349           for
# 5     12349  relationship
# 6     12349            in
# 7     12349         event
# 8     12349           but
# 9     12349           put
# ..      ...           ...
# 9   7784604         after
# 10  7784604            by
# 11  7784604            th
# 12  7784604         haunt
# 13  7784604        tragic
# 14  7784604             t
# 15  7784604        secret
# 16  7784604     occurrenc
# 17  7784604       unravel
# 18  7784604            an
#
# [57615 rows x 2 columns]

# %% [markdown]
# Razpredelnico združimo z razpredelnico žanrov, da dobimo razpredelnico korenov žanrov.

# %%
koreni_zanrov = pd.merge(
    koreni_filmov,
    zanri
)[['koren', 'zanr']]
koreni_zanrov
# Out:
#             koren     zanr
# 0           tramp   Comedy
# 1           tramp    Drama
# 2           tramp   Family
# 3        jeopardy   Comedy
# 4        jeopardy    Drama
# 5        jeopardy   Family
# 6            chil   Comedy
# 7            chil    Drama
# 8            chil   Family
# 9              th   Comedy
# ...           ...      ...
# 152103     secret  Mystery
# 152104  occurrenc    Drama
# 152105  occurrenc   Horror
# 152106  occurrenc  Mystery
# 152107    unravel    Drama
# 152108    unravel   Horror
# 152109    unravel  Mystery
# 152110         an    Drama
# 152111         an   Horror
# 152112         an  Mystery
#
# [152113 rows x 2 columns]

# %% [markdown]
# S pomočjo funkcije `crosstab` preštejemo, kolikokrat se vsaka kombinacija pojavi.

# %%
pojavitve_korenov_po_zanrih = pd.crosstab(koreni_zanrov.koren, koreni_zanrov.zanr)
pojavitve_korenov_po_zanrih
# Out:
# zanr        Action  Adventure  Animation  Biography  Comedy  Crime  Drama  \
# koren
#                710        609        145        135     718    436   1056
# $               69         56          7         37      59     32    123
# aang             1          1          0          0       0      0      0
# aaron            0          0          0          0       2      0      0
# ab               0          0          0          0       1      0      1
# abagnal          0          0          0          1       0      1      1
# abandon          1          3          1          1       3      0      3
# abb              0          0          0          0       1      0      0
# abbey            0          0          0          0       0      1      1
# abby             1          0          0          0       1      0      0
# ...            ...        ...        ...        ...     ...    ...    ...
# zisman           0          0          0          0       1      0      0
# ziss             0          1          0          0       1      0      1
# zodiac           0          0          0          0       0      1      1
# zomb             5          3          1          0       5      0      0
# zon              1          2          0          0       0      0      5
# zorg             1          1          0          0       0      0      0
# zorr             1          1          0          0       1      0      0
# zubrowk          0          1          0          0       1      0      1
# zuckerberg       0          0          0          1       0      0      1
# édith            0          0          0          1       0      0      1
#
# zanr        Family  Fantasy  Film-Noir   ...     Horror  Music  Musical  \
# koren                                    ...
#                129      237          9   ...        236     41       20
# $                6       18          1   ...         26      5        1
# aang             1        0          0   ...          0      0        0
# aaron            0        0          0   ...          0      0        0
# ab               0        0          0   ...          0      0        0
# abagnal          0        0          0   ...          0      0        0
# abandon          3        1          0   ...          0      0        0
# abb              0        0          0   ...          0      0        1
# abbey            0        0          0   ...          0      0        0
# abby             0        1          0   ...          0      0        0
# ...            ...      ...        ...   ...        ...    ...      ...
# zisman           0        0          0   ...          0      0        0
# ziss             0        0          0   ...          0      0        0
# zodiac           0        0          0   ...          0      0        0
# zomb             0        0          0   ...         10      0        0
# zon              0        0          0   ...          1      0        0
# zorg             0        0          0   ...          0      0        0
# zorr             0        0          0   ...          0      0        0
# zubrowk          0        0          0   ...          0      0        0
# zuckerberg       0        0          0   ...          0      0        0
# édith            0        0          0   ...          0      1        0
#
# zanr        Mystery  Romance  Sci-Fi  Sport  Thriller  War  Western
# koren
#                 250      308     273     43       439   37       15
# $                22       23      40      7        44    5        0
# aang              0        0       0      0         0    0        0
# aaron             0        0       0      0         0    0        0
# ab                0        1       0      0         0    0        0
# abagnal           0        0       0      0         0    0        0
# abandon           0        0       1      0         0    0        0
# abb               0        1       0      0         0    0        0
# abbey             1        0       0      0         0    0        0
# abby              0        0       0      0         0    0        0
# ...             ...      ...     ...    ...       ...  ...      ...
# zisman            0        0       0      0         0    0        0
# ziss              0        0       0      0         0    0        0
# zodiac            1        0       0      0         0    0        0
# zomb              0        1       2      0         4    0        0
# zon               0        0       3      0         2    2        0
# zorg              0        0       1      0         0    0        0
# zorr              0        0       0      0         0    0        0
# zubrowk           0        0       0      0         0    0        0
# zuckerberg        0        0       0      0         0    0        0
# édith             0        0       0      0         0    0        0
#
# [7767 rows x 21 columns]

# %% [markdown]
# Iskane verjetnosti sedaj dobimo tako, da vsak stolpec delimo s številom filmov danega žanra. Da ne bomo dobili ničelne verjetnosti pri korenih, ki se v našem vzorcu ne pojavijo, verjetnost malenkost povečamo.

# %%
verjetnosti_korenov_po_zanrih = pojavitve_korenov_po_zanrih / zanri.groupby('zanr').size() + 0.001

# %% [markdown]
# Poglejmo, kaj so najpogostejši koreni pri nekaj žanrih:

# %%
verjetnosti_korenov_po_zanrih.Crime.sort_values(ascending=False).head(20)
# Out:
# koren
#           0.890796
# an        0.682633
# th        0.668347
# t         0.627531
# of        0.523449
# h         0.501000
# in        0.431612
# on        0.227531
# with      0.219367
# by        0.174469
# wh        0.172429
# for       0.166306
# when      0.160184
# from      0.129571
# their     0.129571
# that      0.117327
# after     0.109163
# murder    0.109163
# polic     0.101000
# him       0.101000
# Name: Crime, dtype: float64

# %%
verjetnosti_korenov_po_zanrih.Romance.sort_values(ascending=False).head(20)
# Out:
# koren
#          0.886057
# th       0.641805
# an       0.615943
# t        0.541230
# in       0.457897
# of       0.449276
# h        0.446402
# with     0.308471
# on       0.251000
# her      0.233759
# for      0.207897
# lov      0.202149
# woman    0.159046
# man      0.156172
# wh       0.156172
# that     0.150425
# their    0.147552
# when     0.138931
# young    0.138931
# by       0.136057
# Name: Romance, dtype: float64

# %%
verjetnosti_korenov_po_zanrih['Sci-Fi'].sort_values(ascending=False).head(20)
# Out:
# koren
#          0.939144
# th       0.708904
# t        0.691722
# an       0.681412
# of       0.574883
# in       0.451172
# h        0.365261
# on       0.265605
# with     0.251859
# from     0.196876
# that     0.179694
# for      0.176258
# by       0.159076
# earth    0.148766
# their    0.141893
# after    0.141893
# must     0.141893
# $        0.138457
# alien    0.128148
# ar       0.121275
# Name: Sci-Fi, dtype: float64

# %% [markdown]
# Žanre sedaj določimo tako, da za vsak žanr pomnožimo verjetnost žanra in pogojne verjetnosti vseh korenov, ki nastopajo v opisu filma.

# %%
def doloci_zanre(opis):
    faktorji_zanrov = verjetnosti_zanrov * verjetnosti_korenov_po_zanrih[
        verjetnosti_korenov_po_zanrih.index.isin(
            koreni_besed(opis)
        )
    ].prod()
    faktorji_zanrov /= max(faktorji_zanrov)
    return faktorji_zanrov.sort_values(ascending=False).head(5)

# %%
doloci_zanre('Alien space ship appears above Slovenia.')
# Out:
# zanr
# Horror       1.000000
# Sci-Fi       0.969638
# Action       0.779689
# Adventure    0.632686
# Thriller     0.198417
# dtype: float64

# %%
doloci_zanre('A story about a young mathematician, who discovers her artistic side')
# Out:
# zanr
# Drama        1.000000
# Romance      0.169551
# Biography    0.084672
# Mystery      0.083656
# History      0.075603
# dtype: float64
